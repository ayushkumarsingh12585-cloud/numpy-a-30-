# %%
print("helooo")
# Out:
# helooo

# %%
import numpy as np
a=np.arange(5) 
print(a)
# Out:
# [0 1 2 3 4]

# %%
b=np.arange(2,8)
print(b)
# Out:
# [2 3 4 5 6 7]

# %%
import numpy as np 
a=np.array([1,2,3,4,5])
print(a)
print(a.shape)
print(a.ndim)
# Out:
# [1 2 3 4 5]
# (5,)
# 1

# %%
import numpy as np 
c=np.arange(10,21,2)
print(c)
# Out:
# [10 12 14 16 18 20]

# %%
a=np.arange(1,2,0.2)
print(a)
# Out:
# [1.  1.2 1.4 1.6 1.8]

# %%
a=np.array([1,2,3,4,3,2,4,1,4,5])
result={}
for i in a:
    if i not in result:
        result[int(i)]=1
    else:
        result[int(i)]+=1
print(result)
# Out:
# {1: 2, 2: 2, 3: 2, 4: 3, 5: 1}

# %%
import numpy as np
a=np.array([1,2,3,4])
b=a.view()
b[0]=100
print(a)
print(b)
# Out:
# [100   2   3   4]
# [100   2   3   4]

# %%
import numpy as np 
a=np.array([1,2,3,4])
b=a.copy()
b[0]=100
print(a)
print(b)
# Out:
# [1 2 3 4]
# [100   2   3   4]

# %%
import numpy as np 
a=np.array([1,2,3,4,5,6])
b=a.reshape(2,3)
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
b=a.reshape(3,2)
print(b)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
# minus one
import numpy as np 
a=np.array([1,2,3,4,5,6])
b=a.reshape(2,-1)
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np 
a=np.array([1,2,3,4,5])
b=a.reshape(-1,1)
print(b)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]

# %%
import numpy as np 
a=np.array([1,2,3,4,5])
b=a.reshape(1,-1)
print(b)
# Out:
# [[1 2 3 4 5]]

# %%
# 1d
import numpy as np 
a=np.array([1,2,3,4])
b=np.array([5])
c=np.concatenate((a,b))
print(c)
# Out:
# [1 2 3 4 5]

# %%
#2d
a=np.array([[1,2],[3,4]])
b=np.array([[5,6],[7,8]])
print(np.concatenate((a,b),axis=0))
# Out:
# [[1 2]
#  [3 4]
#  [5 6]
#  [7 8]]

# %%
print(np.concatenate((a,b), axis=1))
# Out:
# [[1 2 5 6]
#  [3 4 7 8]]
